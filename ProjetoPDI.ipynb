# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio as io

import math

# %% [markdown]
# # 1. Rotação

# %%
def rotate(img, ang):
    
    ang = ang*(np.pi/180) #converte de graus para radiano
    r, c = img.shape[0:2] #r = n linhas, c = n colunas
    #desconsidera a linha e a coluna extra adicionadas
    r -= 1
    c -= 1
    #coordenadas do centro da imagem, para rotacionar em volta dele
    ic = r/2
    jc = c/2
    #imagem rotacionada iniciada com zeros. Dimensoes são tais para poder abrigar o maior
    #retangulo rotacionado possível (ang = 45)
    r_rot = int(round(r*np.sqrt(2)))
    c_rot = int(round(c*np.sqrt(2)))
    M_rot = np.zeros((r_rot, c_rot, 3),dtype='uint8')
    #usados para centralizar a imagem rotacionada na imagem de destino, para evitar que 
    #alguns pixels fiquem com indice negativo
    i_cntrlz = int(round((r_rot-r)/2))
    j_cntrlz = int(round((c_rot-c)/2))
    #mapeamento reverso
    M_rev = np.zeros((r,c,3),dtype='uint8')
    M_rot2 = np.zeros((r_rot, c_rot, 3),dtype='uint8')
    
    for i in range(r):
        for j in range(c):
            ##################### mapeamento direto ########################
            il = int(round((i-ic)*np.cos(-ang) - (j-jc)*np.sin(-ang) + ic))
            jl = int(round((i-ic)*np.sin(-ang) + (j-jc)*np.cos(-ang) + jc))
            #centralizar
            il += i_cntrlz
            jl += j_cntrlz
            #tons de cinza
            M_rot[il,jl,0] = img[i,j,0]
            M_rot[il,jl,1] = M_rot[il,jl,0]
            M_rot[il,jl,2] = M_rot[il,jl,0]
            
            ######### mapeamento reverso com interpolacao bilinear #########
            il = int(round((i-ic)*np.cos(-ang) - (j-jc)*np.sin(-ang) + ic))
            jl = int(round((i-ic)*np.sin(-ang) + (j-jc)*np.cos(-ang) + jc))
            x = (il-ic)*np.cos(-ang) + (jl-jc)*np.sin(-ang) + ic
            y = (-1*(il-ic))*np.sin(-ang) + (jl-jc)*np.cos(-ang) + jc
            #montagem do retangulo para interpolar - coordenadas eixo x
            if x < 0:
                x = 0
            if x<i and x>0:
                ii = i-1
            elif x >= i:
                ii = i
            #montagem do retangulo para interpolar - coordenadas eixo y    
            if y < 0:
                y = 0
            if y < j and y > 0:
                jj = j-1
            elif y >= j:
                jj = j
            #interpolacao bilinear
            i_y = img[ii,jj,0] + (y-jj)*(img[ii,jj+1,0] - img[ii,jj,0])
            i_mais_um_y = img[ii+1,jj,0] + (y-jj)*(img[ii+1,jj+1,0] - img[ii+1,jj,0])
            P = i_y + (x-ii)*(i_mais_um_y-i_y)
            #tons de cinza
            M_rev[i,j,0] = P
            M_rev[i,j,1] = M_rev[i,j,0]
            M_rev[i,j,2] = M_rev[i,j,0]
            
            ########## rotacao utilizando interpolacao bilinear ############
            il = int(round((i-ic)*np.cos(-ang) - (j-jc)*np.sin(-ang) + ic))
            jl = int(round((i-ic)*np.sin(-ang) + (j-jc)*np.cos(-ang) + jc))
            il_prox = int(round((i+1-ic)*np.cos(-ang) - (j-jc)*np.sin(-ang) + ic))
            jl_prox = int(round((i-ic)*np.sin(-ang) + (j+1-jc)*np.cos(-ang) + jc))
            #centralizar
            il += i_cntrlz
            jl += j_cntrlz
            il_prox += i_cntrlz
            jl_prox += j_cntrlz
            #pontos a serem interpolados
            ils = np.linspace(il,il_prox,num=il_prox-il+1)
            jls = np.linspace(jl,jl_prox,num=jl_prox-jl+1)
            P = img[i,j,0]
            
            #se i for a ultima linha
            if i+1 == r:
                #se j for a ultima coluna
                if j+1 == c:
                    #tons de cinza
                    M_rot2[il,jl,0] = P
                    M_rot2[il,jl,1] = M_rot2[il,jl,0]
                    M_rot2[il,jl,2] = M_rot2[il,jl,0]
                else:
                    for b in jls:
                        idxj, = np.where(np.isclose(jls,b))
                        b = int(b)
                        #evitar divisao por zero
                        if len(jls) == 1:
                            M_rot2[il,b,0] = P
                            M_rot2[il,b,1] = M_rot2[il,b,0]
                            M_rot2[il,b,2] = M_rot2[il,b,0]
                        else:
                            M_rot2[il,b,0] = P+(idxj/(len(jls)-1))
                            M_rot2[il,b,1] = M_rot2[il,b,0]
                            M_rot2[il,b,2] = M_rot2[il,b,0]
            #se j for a ultima coluna, mas i não for a ultima linha
            elif j+1 == c:
                for a in ils:
                    idxi, = np.where(np.isclose(ils,a))
                    a = int(a)
                    #evitar divisao por zero
                    if len(ils) == 1:
                        M_rot2[a,jl,0] = P
                        M_rot2[a,jl,1] = M_rot2[a,jl,0]
                        M_rot2[a,jl,2] = M_rot2[a,jl,0]
                    else:
                        M_rot2[a,jl,0] = P+(idxi/(len(ils)-1))
                        M_rot2[a,jl,1] = M_rot2[a,jl,0]
                        M_rot2[a,jl,2] = M_rot2[a,jl,0]
            #se nem i nem j forem ultima linha ou ultima coluna
            else:
                for a in ils:
                    for b in jls:
                        idxi, = np.where(np.isclose(ils, a))
                        idxj, = np.where(np.isclose(jls, b))
                        a = int(a)
                        b = int(b)
                        #evitar divisao por zero
                        if len(ils) == 1 and len(jls) == 1:
                            M_rot2[a,b,0] = P
                            M_rot2[a,b,1] = M_rot2[a,b,0]
                            M_rot2[a,b,2] = M_rot2[a,b,0]
                        elif len(ils) == 1:
                            M_rot2[a,b,0] = P+(idxj/(len(jls)-1))
                            M_rot2[a,b,1] = M_rot2[a,b,0]
                            M_rot2[a,b,2] = M_rot2[a,b,0]
                        elif len(jls) == 1:
                            M_rot2[a,b,0] = P+(idxi/(len(ils)-1))
                            M_rot2[a,b,1] = M_rot2[a,b,0]
                            M_rot2[a,b,2] = M_rot2[a,b,0]
                        else:
                            M_rot2[a,b,0] = P+(idxi/(len(ils)-1))+(idxj/(len(jls)-1))
                            M_rot2[a,b,1] = M_rot2[a,b,0]
                            M_rot2[a,b,2] = M_rot2[a,b,0]
            
    return M_rot, M_rev, M_rot2

# %%
img = io.imread("imageio:astronaut.png")
#tons de cinza
img[:,:,1] = img[:,:,0]
img[:,:,2] = img[:,:,0]

#adiciona uma linha e uma coluna na imagem para auxiliar no mapeamento reverso
img_aux = np.zeros((img.shape[0]+1, img.shape[1]+1, 3))
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        for band in range(3):
            img_aux[i,j,band] = img[i,j,0]
        
M_rot, M_rev, M_rot2 = rotate(img_aux, 45)

fig, ax = plt.subplots(1, 4, figsize = (20, 5))

ax[0].set_title('Imagem Original', fontsize=12)
ax[0].set_ylabel('Height', fontsize=12)
ax[0].set_xlabel('Width', fontsize=12)
ax[0].imshow(img)

ax[1].set_title('Rotacao com mapeamento direto', fontsize=12)
ax[1].set_ylabel('Height', fontsize=12)
ax[1].set_xlabel('Width', fontsize=12)
ax[1].imshow(M_rot)

ax[2].set_title('Mapeamento Reverso com interpolacao', fontsize=12)
ax[2].set_ylabel('Height', fontsize=12)
ax[2].set_xlabel('Width', fontsize=12)
ax[2].imshow(M_rev)

ax[3].set_title('Rotacao com interpolacao', fontsize=12)
ax[3].set_ylabel('Height', fontsize=12)
ax[3].set_xlabel('Width', fontsize=12)
ax[3].imshow(M_rot2)

# %% [markdown]
# ## 2. DCT

# %%
def DCT1D(x):
    N = len(x)  
    X = np.zeros(N)   
    Ak = math.sqrt(2.0/N) # amplitude
    nn = 2.0 * N

    for k in range(N):
        ck = math.sqrt(0.5) if k == 0 else 1
        somatorio = 0
        for n in range(N):
            termo1 = 2.0 * math.pi * k * n
            termo2 = k * math.pi

            somatorio += x[n] * math.cos((termo1 + termo2)/nn)
            
        t = Ak * ck

        X[k] = t * somatorio

    return X

# %%
img = io.imread("lena.bmp")
print(img.shape)
img = np.asarray(img)
plt.imshow(img, cmap="gray")
plt.title("lena")
plt.show()
# Out:
# (256, 256)

# %%
def IDCT1D(X):
    N = len(X)
    x = np.zeros(N)
    Ak = math.sqrt(2.0/N)
    nn = 2.0 * N
    
    for n in range(N):
        somatorio = 0
        for k in range(N):
            ck = math.sqrt(0.5) if k == 0 else 1
            termo1 = 2.0 * math.pi * k * n
            termo2 = k * math.pi
                
            somatorio += ck * X[k] * math.cos((termo1 + termo2)/nn)
            
        x[n] = Ak * somatorio
    
    return x

# %%
def DCT2D(img, reverso):
    
    imgDCT = np.zeros(img.shape)

    for i, linha in enumerate(img):
        if reverso == False:
            imgDCT[i] = DCT1D(linha)
        else:
            imgDCT[i] = IDCT1D(linha)

    imgDCT = imgDCT.T #pega transposta

    for j, coluna in enumerate(imgDCT):
        if reverso == False:
            imgDCT[j] = DCT1D(coluna)
        else:
            imgDCT[j] = IDCT1D(coluna)
            
    imgDCT = imgDCT.T
    
    return imgDCT

# %%
imgDCT = DCT2D(img, False)
dc = imgDCT[0][0]
print(f"Nível DC: {dc}")

plt.figure(figsize=[80,8])
plt.imshow(imgDCT, cmap="gray")
plt.title("Com DC")
plt.show()


imgDCT[0][0] = 0
plt.figure(figsize=[80,8])
plt.title("Sem DC")
plt.imshow(imgDCT, cmap="gray")
plt.show()
# Out:
# Nível DC: 25261.12890625001

# %% [markdown]
# # 3. Aproximação

# %%
def aproximar(n):
    dct = np.zeros(img.shape)
    dct = DCT2D(img, False)
    dc = dct[0][0]
    # dicionário para os coeficientes
    coef = []
    if n > 0:
        for i in range(len(dct[0])):
            for j in range(len(dct[1])):
                if i != 0 and j != 0:
                    coef.append({"abs(Value)": abs(dct[i][j]), "Value": dct[i][j], "i": i, "j": j})
        # ordena de forma decrescente pelo valor absoluto, pois pode ter valores negativos
        coefOrdenados = sorted(coef, key = lambda z: z['abs(Value)'], reverse=True)
        # pega os n maiores valores
        maioresCoef = coefOrdenados[:n]
        # zera os coeficientes
        dct.fill(0)

        for c in maioresCoef:
            dct[c['i']][c['j']] = c['Value']
    else:
        dct.fill(0) # manter apenas o dc
    # adiciona dc      
    dct[0][0] = dc
    print(dc)
    
    imgAproximada = DCT2D(dct, True)

    return np.uint8(imgAproximada)


i = np.zeros(img.shape)
i = aproximar(2)
plt.figure(figsize=[80,8])
plt.imshow(i, cmap='gray')
plt.show()
# Out:
# 25261.12890625001

# %% [markdown]
# # 4. Filtro passa-baixas

# %%
def passaBaixasIdeal(img, fc):
    dct = DCT2D(img, False)
    
    dct[: ,fc : ] = 0 # deixa passar as fc primeiras colunas
    dct[fc: , :] = 0 # deixa passar as fc linhas
    
    imgFiltrada = DCT2D(dct, True)
    
    imgFiltrada[imgFiltrada < 0] = 0
    imgFiltrada[imgFiltrada > 255] = 255
    
    
    return np.uint8(imgFiltrada)

# %%
fc = int(input('Digite o valor da frequência: '))

pbi = passaBaixasIdeal(img, fc)
plt.figure()
plt.imshow(pbi, cmap='gray')
plt.show()
# Out:
# Digite o valor da frequência: 50
